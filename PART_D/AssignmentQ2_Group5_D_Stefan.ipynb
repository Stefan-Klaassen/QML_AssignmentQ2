# %%
from AssignmentQ2_Group5_D_Stefan import * # Restart kernel if file changed
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch
from IPython.display import clear_output
clear_output(wait=True)
print('Success, obj:', model.ObjVal) if sol else print('Failed')

tol = 1e-6
# Out:
# Success, obj: 1044.7189730714686

# %%
# Extract solution
solution = []
for v in V:
    print(f"Vehicle {v}:", end=' ')
    route = []
    i = 0
    while True:
        js = [j for j in N if abs(x[i, j, v].X - 1) <= tol]
        assert len(js) <= 1
        if not js: break
        j = int(js[0])
        route.append((i, j))
        if j == 0: break
        i = j
    print(', '.join(f"{a:>2} -> {b:<2}" for a, b in route))
    solution.append(route)
# Out:
# Vehicle 0:  0 -> 5 ,  5 -> 14, 14 -> 15, 15 -> 16, 16 -> 12, 12 -> 0
# Vehicle 1:  0 -> 20, 20 -> 6 ,  6 -> 9 ,  9 -> 11, 11 -> 10, 10 -> 8 ,  8 -> 0
# Vehicle 2:  0 -> 17, 17 -> 13, 13 -> 18, 18 -> 19, 19 -> 0
# Vehicle 3:  0 -> 3 ,  3 -> 2 ,  2 -> 1 ,  1 -> 7 ,  7 -> 4 ,  4 -> 0

# %%
import pandas as pd
for v, route in enumerate(solution):
    if not route: continue
    data = []
    load = 0
    for i, j in route:
        load += q[i]
        data.append({
            'node': f"{i}->{j}",
            'arr_time': tau_a[i, v].X,
            'dep_time': tau_d[i, v].X,
            'travel_time': cd[i][j] * s,
            'arr_charge': beta_a[i, v].X,
            'dep_charge': beta_d[i, v].X,
            'charged': sum(beta_c[i, p, v].X for p in P),
            'has_charger': bs[i],
            'stay_time': tau_d[i, v].X - tau_a[i, v].X,
            'charging_time': ", ".join([f"{p}: {tau_e[i, p, v].X - tau_s[i, p, v].X:.2f}" for p in P if beta_c[i, p, v].X]),
            'service_time': ts[i],
            'load': load,
        })
    df = pd.DataFrame(data)
    print('vehicle:', v)
    print(df)
    print('\n')
# Out:
# vehicle: 0
#      node     arr_time     dep_time  travel_time  arr_charge  dep_charge  \
# 0    0->5     0.000000     0.000000    30.265492    0.000000  110.000000
# 1   5->14    30.265492   120.265492    56.568542   79.734508   79.734508
# 2  14->15   176.834034   266.834034    10.770330   23.165966   23.165966
# 3  15->16   277.604364   367.604364    10.000000   12.395636   96.157731
# 4  16->12   934.000000  1263.842269    10.000000   86.157731   86.157731
# 5   12->0  1273.842269  1363.842269    76.157731   76.157731   76.157731
#
#    charged  has_charger   stay_time       charging_time  service_time  load
# 0      0.0            0    0.000000                                 0     0
# 1      1.0            0   90.000000             0: 0.00            90    10
# 2      1.0            0   90.000000             0: 0.00            90    20
# 3      2.0            1   90.000000  0: 72.40, 1: 11.37            90    60
# 4      0.0            0  329.842269                                90   100
# 5      0.0            0   90.000000                                90   120
#
#
# vehicle: 1
#      node     arr_time     dep_time  travel_time  arr_charge  dep_charge  \
# 0   0->20     0.000000     0.000000    20.000000    0.000000  110.000000
# 1   20->6    20.000000   464.750969    32.249031   90.000000   90.000000
# 2    6->9   497.000000   587.000000    60.926185   57.750969   93.233846
# 3   9->11   744.692339   834.692339    14.142136   32.307661   32.307661
# 4  11->10   848.834475   938.834475     6.000000   18.165525   18.165525
# 5   10->8   944.834475  1034.834475    12.165525   12.165525   12.165525
# 6    8->0  1047.000000  1416.676192    23.323808    0.000000   23.323808
#
#    charged  has_charger   stay_time charging_time  service_time  load
# 0      0.0            0    0.000000                           0     0
# 1      1.0            0  444.750969       1: 0.00            90    10
# 2      1.0            1   90.000000      1: 35.48            90    30
# 3      0.0            0   90.000000                          90    40
# 4      0.0            0   90.000000                          90    50
# 5      0.0            0   90.000000                          90    60
# 6      1.0            1  369.676192      3: 23.32            90    80
#
#
# vehicle: 2
#      node  arr_time  dep_time  travel_time  arr_charge  dep_charge  charged  \
# 0   0->17       0.0       0.0    66.603303    0.000000  110.000000      0.0
# 1  17->13     311.0     401.0     8.000000   43.396697   43.396697      0.0
# 2  13->18     409.0     728.0    14.000000   35.396697   35.396697      0.0
# 3  18->19     742.0     832.0    10.000000   21.396697   88.102497      1.0
# 4   19->0     842.0     932.0    78.102497   78.102497   78.102497      0.0
#
#    has_charger  stay_time charging_time  service_time  load
# 0            0        0.0                           0     0
# 1            0       90.0                          90    20
# 2            0      319.0                          90    50
# 3            1       90.0      1: 66.71            90    70
# 4            0       90.0                          90    80
#
#
# vehicle: 3
#    node     arr_time     dep_time  travel_time  arr_charge  dep_charge  \
# 0  0->3     0.000000     0.000000    58.137767    0.000000  110.000000
# 1  3->2    67.000000   178.941227    34.058773   51.862233   51.862233
# 2  2->1   213.000000   303.000000    17.204651   17.803460   17.803460
# 3  1->7   320.204651   410.204651    15.620499    0.598809   24.564771
# 4  7->4  1073.000000  1163.000000     8.944272    8.944272    8.944272
# 5  4->0  1171.944272  1388.775006    51.224994    0.000000   51.224994
#
#    charged  has_charger   stay_time      charging_time  service_time  load
# 0      0.0            0    0.000000                                0     0
# 1      1.0            0  111.941227            0: 0.00            90    10
# 2      1.0            0   90.000000            0: 0.00            90    40
# 3      2.0            1   90.000000  0: 23.97, 1: 0.00            90    50
# 4      0.0            0   90.000000                               90    70
# 5      1.0            1  216.830734           3: 51.22            90    80

# %%
# Plotting points
x_coords = []
y_coords = []
for n in node_data:
    x_coords.append(n.XCOORD)
    y_coords.append(n.YCOORD)
plt.scatter(x_coords, y_coords, color='red')
plt.text(node_data[0].XCOORD, node_data[0].YCOORD, 'Depot', fontsize=9, ha='right')
for i, n in enumerate(node_data[1:], start=1):
    plt.text(n.XCOORD, n.YCOORD, f'{i}', fontsize=9, ha='right')

# Plotting the routes put arrows between the nodes
cmap = plt.get_cmap('tab10')
for v, route in enumerate(solution):
    if not route: continue
    color = cmap(v % 10)
    plt.plot([], [], color=color, label=f'Vehicle {v+1}')
    ax = plt.gca()
    for i_idx, j_idx in route:
        x1, y1 = node_data[i_idx].XCOORD, node_data[i_idx].YCOORD
        x2, y2 = node_data[j_idx].XCOORD, node_data[j_idx].YCOORD
        if x1 == x2 and y1 == y2:
            continue
        arr = FancyArrowPatch((x1, y1), (x2, y2),
                                arrowstyle='-|>', mutation_scale=12,
                                color=color, linewidth=1.5,
                                shrinkA=3, shrinkB=3)
        ax.add_patch(arr)

plt.title('Vehicle Routes')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.legend()
plt.grid()
plt.show()
